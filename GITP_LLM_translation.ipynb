# %% [markdown]
# # This script translates transcripts of video simulation role-playing exercises from Dutch to English

# %%
# Install libraries that might not be installed as necessary (adjust manually) through Anaconda prompt

# %%
# Import necessary libraries
# import openai          # OpenAI API for AI model access
# from openai import OpenAI  # The main client class for interacting with OpenAI's API
from openai import AzureOpenAI
import requests        # HTTP library for making web requests (API calls, downloading data, etc.)
import re              # Regular expressions
import os              # Operating system interface
import pandas as pd    # DataFrames for tabular data manipulation and analysis
import numpy as np     # Numerical computing
import openpyxl        # Import excel files
import time            # Time-related functions
import random          # Random number generation
import getpass         # pop-up window for API completion
from tqdm import tqdm  # for showing progress bars

# set seed for reproducibility
random.seed(1337)  # Sets seed for Python's random module

# %%
# Load data
test_text = pd.read_csv("input/data_gitp_text.csv")
# test_text = test_text.iloc[:50] # keep only first few rows for pilot data analysis purposes
test_text.head()

# # Text data
# text_data = pd.read_csv("data_gitp_text.csv")
# Out:
#         id                                    Beoordeling.607  \
# 0  1460133  Oh ja, Carina ik kan me voorstellen dat je voo...
# 1  1462073  Marine, ja, ik begrijp inderdaad dat jij het d...
# 2  1549902  Dacht je landen, ja, fijn dat je dat je even l...
# 3  1552130  Hoi marine, leuk om met je samen te werken. Zo...
# 4  1569467  Hoe landen nou fijn dat we elkaar even spreken...
#
#                                      Beoordeling.608  \
# 0  Jeetje ik, ik kan me voorstellen dat je dat la...
# 1  Oh, ik had eigenlijk dat beeld niet of collega...
# 2  Ja, ik kan me voorstellen dat het erg lastig i...
# 3  Fijn om te horen dat je volgende week meer rui...
# 4  Ik begrijp dat oh, ik begrijp. Ik begrijp dat ...
#
#                                      Beoordeling.609  \
# 0  Ja, dus als ik het zo hoor, dan is er dus eige...
# 1  Ja, als jij het gaat presenteren en ik doe het...
# 2  Ja, ik kan me voorstellen dat het dat het last...
# 3  Heel goed dat je je eigen kwaliteiten erkent e...
# 4  Hoe zou, hoe zou de rest van het team jou kunn...
#
#                                      Beoordeling.610  \
# 0  Ik denk dat het goed is als we, zoals ik net a...
# 1  Nou, maar, dat dank je wel, in ieder geval, ik...
# 2  Ja, waar we het natuurlijk over hebben gehad, ...
# 3  Nou heel vaak dat ze dus het dario er iets and...
# 4  Nou, allereerst, dank je wel dat je nou zo ope...
#
#                                      Beoordeling.all
# 0  Oh ja, Carina ik kan me voorstellen dat je voo...
# 1  Marine, ja, ik begrijp inderdaad dat jij het d...
# 2  Dacht je landen, ja, fijn dat je dat je even l...
# 3  Hoi marine, leuk om met je samen te werken. Zo...
# 4  Hoe landen nou fijn dat we elkaar even spreken...

# %% [markdown]
# # Prompt

# %%
# Prompt for Dutch-to-English translation
translation_prompt = """
Translate the following text from Dutch to English.

Context:
- The text comes from a spoken role-playing exercise.
- It was automatically transcribed, so it may contain filler words, hesitation markers, partial sentences, and transcription glitches.

Translation Requirements:
- Convey the intended meaning in fluent English (do NOT translate word-by-word).
- Preserve the *structure* of the utterances: sentence breaks, pacing, repetitions, interruptions, and unfinished thoughts.
- Keep all disfluencies (e.g., "uh", "hm", false starts, repeated words).
- If the transcript contains unclear or broken phrases, translate them as equally unclear or broken in English, without fixing them.
- Do NOT correct grammar, do NOT rewrite into cleaner English, do NOT summarize, and do NOT interpret beyond what is explicitly said.

In other words: translate meaningfully, but keep the *messiness* of spoken language intact.

Text to translate:
```{text}```
"""

# %% [markdown]
# # Open AI

# %%
# Import OpenAI API key
gpt_api_key = getpass.getpass("Enter API key for OpenAI: ") # manually enter API key to the pop-up window
# Initialize the OpenAI client with your API key
client = OpenAI(api_key=gpt_api_key)

# %% [markdown]
# # Azure API key

# %%
# Import Azure OpenAI API key
azure_api_key = getpass.getpass("Enter API key for Azure OpenAI: ") # manually enter API key to the pop-up window

# Import Azure OpenAI endpoint
azure_endpoint = getpass.getpass("Enter Azure OpenAI endpoint URL: ") # manually enter endpoint URL

api_version = "2024-12-01-preview"

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=azure_endpoint,
    api_key=azure_api_key,
)

# %%
# # Import Azure OpenAI API key
# azure_api_key = getpass.getpass("Enter API key for Azure OpenAI: ") # manually enter API key to the pop-up window

# # Import Azure OpenAI endpoint
# azure_endpoint = getpass.getpass("Enter Azure OpenAI endpoint URL: ") # manually enter endpoint URL

# # Initialize the OpenAI client with your Azure API key and endpoint
# client = OpenAI(
#     api_key=azure_api_key,
#     base_url=azure_endpoint.strip()
# )

# %% [markdown]
# ## OpenAI: Function to translate text from Dutch to English

# %%
# set defaul parameters
model = "gpt-4.1-mini" # manually change the model
# deployment = "gpt-4.1-mini" # manually change the model
temperature = 0      # manually change the temperature

# Function to get_translation
def get_translation(client, text, prompt_template, model=model):
    try:
        full_prompt = prompt_template.format(text=text.strip())

        response = client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": "You are a translation engine."},
                {"role": "user", "content": full_prompt}
            ],
            temperature=temperature,  # low temperature for more deterministic output
            max_completion_tokens=10000
        )

        return response.choices[0].message.content.strip()

    except Exception as e:
        print(f"Translation error: {e}")
        return None

# %% [markdown]
# ## Azure: Function to translate text

# %%
# Set default parameters
# model = "gpt-4.1-mini" # manually change the model
deployment = "gpt-4.1-mini" # manually change the model # This is the custom name you gave in Azure AI Studio, e.g., "my-gpt4-deployment"
temperature = 0      # manually change the temperature

# Function to get_translation
def get_translation(client, text, prompt_template):
    try:
        full_prompt = prompt_template.format(text=text.strip())

        response = client.chat.completions.create(
            model=deployment,  # Use the deployment name here
            messages=[
                {"role": "system", "content": "You are a translation engine."},
                {"role": "user", "content": full_prompt}
            ],
            temperature=temperature,
            max_completion_tokens=10000              
        )

        return response.choices[0].message.content.strip()

    except Exception as e:
        print(f"Translation error: {e}")
        return None

# %% [markdown]
# # Text translation

# %%
# Set parameters
columns_to_translate = ["Beoordeling.607", "Beoordeling.608", "Beoordeling.609", "Beoordeling.610"]
df = test_text # manually CHANGE the dataframe to be analyzed

# Add placeholder columns for the translations
for col in columns_to_translate:
    df[f"en_{col}"] = df[col].astype(object)

# Translation loop
for idx, row in df.iterrows():
    for col in columns_to_translate:
        text = row[col]
        if pd.notna(text) and text.strip():
            translated = get_translation(client, text, translation_prompt)
            df.loc[idx, f"en_{col}"] = translated

    if (idx + 1) % 5 == 0:
        print(f"Translated {idx + 1}/{len(df)} rows")
    time.sleep(0.1)

df.head()
# Out:
# Translated 5/893 rows
# Translated 10/893 rows
# Translated 15/893 rows
# Translated 20/893 rows
# Translated 25/893 rows
# Translated 30/893 rows
# Translated 35/893 rows
# Translated 40/893 rows
# Translated 45/893 rows
# Translated 50/893 rows
# Translated 55/893 rows
# Translated 60/893 rows
# Translated 65/893 rows
# Translated 70/893 rows
# Translated 75/893 rows
# Translated 80/893 rows
# Translated 85/893 rows
# Translated 90/893 rows
# Translated 95/893 rows
# Translated 100/893 rows
# Translated 105/893 rows
# Translated 110/893 rows
# Translated 115/893 rows
# Translated 120/893 rows
# Translated 125/893 rows
# Translated 130/893 rows
# Translated 135/893 rows
# Translated 140/893 rows
# Translated 145/893 rows
# Translated 150/893 rows
# Translated 155/893 rows
# Translated 160/893 rows
# Translated 165/893 rows
# Translated 170/893 rows
# Translated 175/893 rows
# Translated 180/893 rows
# Translated 185/893 rows
# Translated 190/893 rows
# Translated 195/893 rows
# Translated 200/893 rows
# Translated 205/893 rows
# Translated 210/893 rows
# Translated 215/893 rows
# Translated 220/893 rows
# Translated 225/893 rows
# Translated 230/893 rows
# Translated 235/893 rows
# Translated 240/893 rows
# Translated 245/893 rows
# Translated 250/893 rows
# Translated 255/893 rows
# Translated 260/893 rows
# Translated 265/893 rows
# Translated 270/893 rows
# Translated 275/893 rows
# Translated 280/893 rows
# Translated 285/893 rows
# Translated 290/893 rows
# Translated 295/893 rows
# Translated 300/893 rows
# Translated 305/893 rows
# Translated 310/893 rows
# Translated 315/893 rows
# Translated 320/893 rows
# Translated 325/893 rows
# Translated 330/893 rows
# Translated 335/893 rows
# Translated 340/893 rows
# Translated 345/893 rows
# Translation error: 'NoneType' object has no attribute 'strip'
# Translated 350/893 rows
# Translated 355/893 rows
# Translated 360/893 rows
# Translated 365/893 rows
# Translated 370/893 rows
# Translated 375/893 rows
# Translated 380/893 rows
# Translated 385/893 rows
# Translated 390/893 rows
# Translated 395/893 rows
# Translated 400/893 rows
# Translated 405/893 rows
# Translated 410/893 rows
# Translated 415/893 rows
# Translated 420/893 rows
# Translated 425/893 rows
# Translated 430/893 rows
# Translated 435/893 rows
# Translated 440/893 rows
# Translated 445/893 rows
# Translated 450/893 rows
# Translated 455/893 rows
# Translated 460/893 rows
# Translated 465/893 rows
# Translated 470/893 rows
# Translated 475/893 rows
# Translated 480/893 rows
# Translated 485/893 rows
# Translated 490/893 rows
# Translated 495/893 rows
# Translated 500/893 rows
# Translated 505/893 rows
# Translated 510/893 rows
# Translated 515/893 rows
# Translated 520/893 rows
# Translated 525/893 rows
# Translated 530/893 rows
# Translated 535/893 rows
# Translated 540/893 rows
# Translated 545/893 rows
# Translated 550/893 rows
# Translated 555/893 rows
# Translated 560/893 rows
# Translated 565/893 rows
# Translated 570/893 rows
# Translated 575/893 rows
# Translated 580/893 rows
# Translated 585/893 rows
# Translated 590/893 rows
# Translated 595/893 rows
# Translated 600/893 rows
# Translated 605/893 rows
# Translated 610/893 rows
# Translated 615/893 rows
# Translated 620/893 rows
# Translated 625/893 rows
# Translated 630/893 rows
# Translated 635/893 rows
# Translated 640/893 rows
# Translated 645/893 rows
# Translated 650/893 rows
# Translated 655/893 rows
# Translated 660/893 rows
# Translated 665/893 rows
# Translated 670/893 rows
# Translated 675/893 rows
# Translated 680/893 rows
# Translated 685/893 rows
# Translated 690/893 rows
# Translated 695/893 rows
# Translated 700/893 rows
# Translated 705/893 rows
# Translated 710/893 rows
# Translated 715/893 rows
# Translated 720/893 rows
# Translated 725/893 rows
# Translated 730/893 rows
# Translated 735/893 rows
# Translated 740/893 rows
# Translated 745/893 rows
# Translated 750/893 rows
# Translated 755/893 rows
# Translated 760/893 rows
# Translated 765/893 rows
# Translated 770/893 rows
# Translated 775/893 rows
# Translated 780/893 rows
# Translated 785/893 rows
# Translated 790/893 rows
# Translated 795/893 rows
# Translated 800/893 rows
# Translated 805/893 rows
# Translated 810/893 rows
# Translated 815/893 rows
# Translated 820/893 rows
# Translated 825/893 rows
# Translated 830/893 rows
# Translated 835/893 rows
# Translated 840/893 rows
# Translated 845/893 rows
# Translated 850/893 rows
# Translated 855/893 rows
# Translated 860/893 rows
# Translated 865/893 rows
# Translated 870/893 rows
# Translated 875/893 rows
# Translated 880/893 rows
# Translated 885/893 rows
# Translated 890/893 rows
# Translation error: 'NoneType' object has no attribute 'strip'
#         id                                    Beoordeling.607  \
# 0  1460133  Oh ja, Carina ik kan me voorstellen dat je voo...
# 1  1462073  Marine, ja, ik begrijp inderdaad dat jij het d...
# 2  1549902  Dacht je landen, ja, fijn dat je dat je even l...
# 3  1552130  Hoi marine, leuk om met je samen te werken. Zo...
# 4  1569467  Hoe landen nou fijn dat we elkaar even spreken...
#
#                                      Beoordeling.608  \
# 0  Jeetje ik, ik kan me voorstellen dat je dat la...
# 1  Oh, ik had eigenlijk dat beeld niet of collega...
# 2  Ja, ik kan me voorstellen dat het erg lastig i...
# 3  Fijn om te horen dat je volgende week meer rui...
# 4  Ik begrijp dat oh, ik begrijp. Ik begrijp dat ...
#
#                                      Beoordeling.609  \
# 0  Ja, dus als ik het zo hoor, dan is er dus eige...
# 1  Ja, als jij het gaat presenteren en ik doe het...
# 2  Ja, ik kan me voorstellen dat het dat het last...
# 3  Heel goed dat je je eigen kwaliteiten erkent e...
# 4  Hoe zou, hoe zou de rest van het team jou kunn...
#
#                                      Beoordeling.610  \
# 0  Ik denk dat het goed is als we, zoals ik net a...
# 1  Nou, maar, dat dank je wel, in ieder geval, ik...
# 2  Ja, waar we het natuurlijk over hebben gehad, ...
# 3  Nou heel vaak dat ze dus het dario er iets and...
# 4  Nou, allereerst, dank je wel dat je nou zo ope...
#
#                                      Beoordeling.all  \
# 0  Oh ja, Carina ik kan me voorstellen dat je voo...
# 1  Marine, ja, ik begrijp inderdaad dat jij het d...
# 2  Dacht je landen, ja, fijn dat je dat je even l...
# 3  Hoi marine, leuk om met je samen te werken. Zo...
# 4  Hoe landen nou fijn dat we elkaar even spreken...
#
#                                   en_Beoordeling.607  \
# 0  Oh yeah, Carina, I can imagine you're facing a...
# 1  Marine, yeah, I do understand that you’re busy...
# 2  Did you think countries, yeah, nice that you c...
# 3  Hi Marine, nice to work with you. Like you sai...
# 4  How nice that we’re talking to each other now,...
#
#                                   en_Beoordeling.608  \
# 0  Wow, I, I can imagine that you find it difficu...
# 1  Oh, I actually didn’t have that image of wheth...
# 2  Yeah, I can imagine it’s really difficult when...
# 3  Nice to hear that next week you seem to have m...
# 4  I understand that oh, I understand. I understa...
#
#                                   en_Beoordeling.609  \
# 0  Yeah, so if I hear it like this, then there’s ...
# 1  Yeah, if you’re going to present it and I do t...
# 2  Yeah, I can imagine that it that it’s difficul...
# 3  Very good that you recognize your own qualitie...
# 4  How would, how would the rest of the team be a...
#
#                                   en_Beoordeling.610
# 0  I think it’s good if we, like I just said, sta...
# 1  Well, but, thanks for that, anyway, I’m glad t...
# 2  Yes, what we of course talked about is that yo...
# 3  Well very often that they, uh, Dario thinks so...
# 4  Well, first of all, thank you for being so ope...

# %%
# Concatenate translated columns into en_Beoordeling.all
translated_columns = [f"en_{col}" for col in columns_to_translate]

# Replace NaN with empty strings before concatenation
test_text["en_Beoordeling.all"] = test_text[translated_columns].fillna("").agg(" ".join, axis=1).str.strip()

# %%
# Optional: Save results
test_text.to_csv('test_text_nl_en.csv', index=False)
test_text.to_excel('test_text_nl_en.xlsx', index=False)
